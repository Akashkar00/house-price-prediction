# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                     property_name property_type  \
# 0  4 Bedroom House for sale in Sector 70A Gurgaon         house
# 1     2 Bedroom House for sale in Sector-33 Sohna         house
# 2                3 BHK Flat in Sector 102 Gurgaon          flat
# 3                3 BHK Flat in Sector 102 Gurgaon          flat
# 4                 3 BHK Flat in Sector 85 Gurgaon          flat
#
#                                     society  price  price_per_sqft    area  \
# 0                      bptp astaire gardens   6.50         27871.0  2332.0
# 1  central park flower valley cerise floors   1.35         11157.0  1210.0
# 2                    conscient heritage max   1.82          9371.0  1942.0
# 3                      emaar gurgaon greens   1.45          8787.0  1650.0
# 4                               ss the leaf   2.00          8305.0  2408.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                           Plot area 299(250 sq.m.)        4         4
# 1                 Built Up area: 1210 (112.41 sq.m.)        2         2
# 2             Super Built up area 1942(180.42 sq.m.)        3         4
# 3  Super Built up area 1650(153.29 sq.m.)Built Up...        3         3
# 4             Super Built up area 2408(223.71 sq.m.)        3         4
#
#   balcony                      additionalRoom  \
# 0      3+  study room,servant room,pooja room
# 1       2                          study room
# 2      3+                        servant room
# 3       3                        servant room
# 4       3                        servant room
#
#                                       address  floorNum      facing  \
# 0   678, Sector 70A Gurgaon, Gurgaon, Haryana       2.0  North-East
# 1           Sector-33 Sohna, Gurgaon, Haryana       4.0        East
# 2   N/a, Sector 102 Gurgaon, Gurgaon, Haryana      15.0        East
# 3  Flat, Sector 102 Gurgaon, Gurgaon, Haryana       8.0  North-East
# 4   B675, Sector 85 Gurgaon, Gurgaon, Haryana       8.0        East
#
#       agePossession                                    nearbyLocations  \
# 0   0 to 1 Year Old  ['Sector 54 Chowk Metro Station', 'Airia Mall'...
# 1   0 to 1 Year Old  ['Sector 55-56, Sector 56', 'M3m 65th Avenue M...
# 2  5 to 10 Year Old  ['Huda Metro Station', 'Ocus Medley Mall', 'Th...
# 3   1 to 5 Year Old  ['JMS Marine Square Mall', 'Dwarka Expressway'...
# 4   1 to 5 Year Old  ['Sapphire 83 Mall', 'Dwarka Expressway', 'Cen...
#
#                                          description  \
# 0  Project overview\nHighlights:\nVisionnaire hom...
# 1  Ready to move in semi furnished luxury low ris...
# 2  Situated in sector 102 gurgaon, conscient heri...
# 3  This 3 bhk apartment is available for sale in ...
# 4  Ss the leaf is one of gurgaon's most sought af...
#
#                                       furnishDetails  \
# 0  ['5 Wardrobe', '9 Fan', '5 Geyser', '1 Stove',...
# 1  ['3 Fan', '1 Fridge', '1 Washing Machine', '1 ...
# 2  ['5 AC', '1 Modular Kitchen', '1 Chimney', 'No...
# 3  ['1 Chimney', '1 Modular Kitchen', '6 AC', 'No...
# 4  ['3 Wardrobe', '5 Fan', '5 Light', '1 Modular ...
#
#                                             features  \
# 0  ['Centrally Air Conditioned', 'Water purifier'...
# 1  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 2  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 3  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 4  ['Intercom Facility', 'Lift(s)', 'Maintenance ...
#
#                                               rating
# 0  ['Environment5 out of 5', 'Safety4 out of 5', ...
# 1                                                NaN
# 2  ['Green Area5 out of 5', 'Construction5 out of...
# 3  ['Green Area5 out of 5', 'Construction4 out of...
# 4  ['Green Area4.5 out of 5', 'Construction4.5 ou...

# %%
df.to_csv('gurgaon_properties.csv',index=False)

# %%
df = pd.read_csv('gurgaon_properties.csv')

# %%
df.shape
# Out:
# (3961, 20)
